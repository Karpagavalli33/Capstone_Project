# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Pre_AI_companies.csv")

# %%
df
# Out:
#      Company Name                                Description    Headquarters  \
# 0   Alibaba Cloud                Best for Big Data Analytics           China
# 1       DataRobot        Best for Automated Machine Learning   Massachusetts
# 2          Google                    Best for AI Development      California
# 3    Hugging Face  Best for Deploying AI Models in the Cloud        New York
# 4          H2O.ai           Best for Time Series Forecasting      California
# ..            ...                                        ...             ...
# 95           Nuro              Best for Driverless Operation      California
# 96        Pony.ai             Best for Robotruck Development      California
# 97          Tesla                 Best for Electric Vehicles           Texas
# 98          Waymo            Best for Experience and Testing      California
# 99           Zoox                 Best for Robotaxi Services      California
#
#     Founded  Annual Revenue  Glassdoor Score
# ...

# %% [markdown]
# ## 1.List the 5 companies, that has the highest Annual Revenue

# %%
Max_Annual_Revenue = df.sort_values(by="Annual Revenue", ascending=False).head(5)

# %%
Max_Annual_Revenue
# Out:
#    Company Name                                        Description  \
# 42       Amazon     Best for Managing and Analyzing Large Datasets
# 2        Google                            Best for AI Development
# 39    Microsoft  Best for Advanced Data Analysis and Predictive...
# 97        Tesla                         Best for Electric Vehicles
# 67      Tencent            Best for Social Media and Communication
#
#                         Headquarters   Founded  Annual Revenue  \
# 42   Washington; Arlington, Virginia  1994.000        574790.0
# 2                         California  1998.000        305600.0
# 39                        Washington  1984.375        211000.0
# 97                             Texas  2003.000         96770.0
# 67                             China  1998.000         85000.0
#
#     Glassdoor Score
# 42         3.750000
# 2          4.450000
# 39         4.350000
# 97         3.650000
# 67         3.945652

# %% [markdown]
# ## 2.Which country has maximum no of AI Companies

# %%
country_counts = df["Headquarters"].value_counts()
top_country = country_counts.idxmax()  # Gets the country with the highest count
max_count = country_counts.max()  # Gets the count of AI companies in that country
print(f"The country with the most AI companies is {top_country} with {max_count} companies.")
# Out:
# The country with the most AI companies is  California with 38 companies.

# %% [markdown]
# ## 3.List the 10 companies having the highest Glassdoor Score

# %%
High_Glassdoor_score = df.sort_values(by="Glassdoor Score", ascending=False).head(10)

# %%
High_Glassdoor_score
# Out:
#                  Company Name  \
# 62                Via Science
# 82                  DataToBiz
# 21                SentinelOne
# 71                   Signifyd
# 92                     Skydio
# 88            Boston Dynamics
# 37                 Analytics8
# 35  AIMLEAP Outsource BigData
# 14           Zoho Corporation
# 76                    Suki AI
#
#                                           Description     Headquarters  \
# 62          Best for Web3-Native Security and Privacy    Massachusetts
# 82               Best for Data-Driven Decision-Making   United Kingdom
# 21       Best for Autonomous Response to Cyberthreats       California
# 71                      Best for Chargeback Guarantee       California
# 92                Best for Autonomous Drone Solutions       California
# 88                  Best for Research and Development    Massachusetts
# 37  Best for Accelerating the Development of Data ...         Illinois
# ...

# %%
plt.figure(figsize=(12,7))
sns.violinplot(x="Headquarters",y="Glassdoor Score",data=High_Glassdoor_score)
plt.show()

# %% [markdown]
# ## 4.List of No of Companies found between the year 2015 to 2024

# %%
companies_2015_2024 = df[(df["Founded"] >= 2015) & (df["Founded"] <= 2024)]

# %%
no_of_companies=companies_2015_2024.shape[0]

# %%
print("Number of companies between the year 2015 to 2024 is: ",no_of_companies)
# Out:
# Number of companies between the year 2015 to 2024 is:  27

# %%
companies_2015_2024
# Out:
#           Company Name                                        Description  \
# 3         Hugging Face          Best for Deploying AI Models in the Cloud
# 5                 Rasa   Best for Managing Conversational AI Applications
# 6            Replicate        Best for Scalability and Cost-Effectiveness
# 8              ClickUp                        Best for Project Management
# 16             CUJO AI                 Best for Advanced Network Security
# 19       Deep Instinct  Best for Deep Learning-Based Threat Prevention...
# 36               Akkio          Best for Data Cleaning and Transformation
# 52           People.ai                            Best for Sales Coaching
# 53             Phrasee        Best for High-Performing Marketing Language
# 60          GE Vernova                        Best for Wind Turbine Model
# 62         Via Science          Best for Web3-Native Security and Privacy
# 63              Xanadu                         Best for Quantum Computing
# ...

# %% [markdown]
# ## 5.List the No of Companies found between the year 1984 to 2014

# %%
companies_1984_2014 = df[(df["Founded"] >= 1984) & (df["Founded"] <= 2014)]

# %%
companies_1984_2014
# Out:
#       Company Name                                       Description  \
# 0    Alibaba Cloud                       Best for Big Data Analytics
# 1        DataRobot               Best for Automated Machine Learning
# 2           Google                           Best for AI Development
# 4           H2O.ai                  Best for Time Series Forecasting
# 7   ActiveCampaign           Best for Email and Marketing Automation
# ..             ...                                               ...
# 91          iRobot  Best for Consumer and Military Robotic Solutions
# 92          Skydio               Best for Autonomous Drone Solutions
# 93      AEye, Inc.                         Best for Adaptive Sensing
# 97           Tesla                        Best for Electric Vehicles
# 99            Zoox                        Best for Robotaxi Services
#
#       Headquarters  Founded  Annual Revenue  Glassdoor Score
# 0            China   2009.0           479.5             3.75
# ...

# %%
# Convert 'Founded' column to numeric (if it contains valid year values)
companies_1984_2014['Founded'] = pd.to_numeric(companies_1984_2014['Founded'], errors='coerce')
companies_1984_2014['Company Name'] = pd.to_numeric(companies_1984_2014['Company Name'], errors='coerce')
# Now, try plotting again
plt.figure(figsize=(12,7))
sns.jointplot(data=companies_1984_2014, x='Annual Revenue', y='Founded', palette="coolwarm", kind='hex')
plt.title('Foundation of the Year vs Revenue', fontsize=16)
plt.xlabel('Annual Revenue', fontsize=14)
# Out:
# C:\Users\Karpagavalli\AppData\Local\Temp\ipykernel_26700\3111327994.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   companies_1984_2014['Founded'] = pd.to_numeric(companies_1984_2014['Founded'], errors='coerce')
# C:\Users\Karpagavalli\AppData\Local\Temp\ipykernel_26700\3111327994.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   companies_1984_2014['Company Name'] = pd.to_numeric(companies_1984_2014['Company Name'], errors='coerce')
# Text(0.5, 36.72222222222221, 'Annual Revenue')

# %% [markdown]
# ## 6.Which Country has the first AI Company?

# %%
# Find the earliest year an AI company was founded
df['Founded']=df['Founded'].astype(int)
earliest_year = df["Founded"].min()

# Get the first AI company (or companies) founded in that year
first_ai_companies = df[df["Founded"] == earliest_year]

# Get the country of the first AI company
first_ai_country = first_ai_companies["Headquarters"].unique()

#print(f"The first AI company was founded in the year {earliest_year}.")
#print(f"Country(ies) with the first AI company: {', '.join(first_ai_country)}")
#print("List of first AI companies:")
#print(first_ai_companies)

earliest_year

# %%
first_ai_companies

# %%
first_ai_country

# %% [markdown]
# ## 7.Compare the Annual Revenue and Glassdoor Score of older companies with new companies

# %%
# Split the dataset into older and newer companies
older_companies = df[df["Founded"] < 2015]
newer_companies = df[df["Founded"] >= 2015]

# Get the statistics for older and newer companies
older_summary = older_companies[["Glassdoor Score", "Annual Revenue"]].describe()
newer_summary = newer_companies[["Glassdoor Score", "Annual Revenue"]].describe()

# Combine the statistics for comparison
comparison_table = pd.concat([older_summary, newer_summary], axis=1)

# Rename the columns to indicate 'Older Companies' and 'Newer Companies'
comparison_table.columns = ['Older Companies - Glassdoor Score','Older Companies - Annual Revenue','Newer Companies - Glassdoor Score', 'Newer Companies - Annual Revenue']

# Print the comparison table
comparison_table

# %% [markdown]
# ## 8. What are the companies are having the best performance in past 5 years?

# %%
# Filter companies founded in the past 5 years (2018–2024)
recent_companies = df[(df["Founded"] >= 2018) & (df["Founded"] <= 2024)]

# Sort by Glassdoor Score and Annual Revenue (you can prioritize one over the other)
best_performers = recent_companies.sort_values(by=["Glassdoor Score", "Annual Revenue"], ascending=False)

# Display the top 10 best-performing companies in the last 5 years
best_performers

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x=recent_companies["Founded"], y=best_performers["Glassdoor Score"], palette="coolwarm",hue=best_performers["Annual Revenue"])
plt.xlabel("Year Founded")
plt.ylabel("Glassdoor Score")
plt.title("Year Founded vs Glassdoor Score")
plt.show()
